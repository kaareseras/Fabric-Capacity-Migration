# %% [markdown]
# # Migrate capacities

# %% [markdown]
# Attach a Lakehouse to provide compute rescources. Create a new if you dont have an existing
#
# original script can be found here: https://github.com/microsoft/semantic-link-labs
#
# Always insert name of Capacities and Workspaces. NOT IDs

# %% [markdown]
# # Install the latest .whl package

# %%
# %pip install semantic-link-labs

import sempy_labs as labs
import sempy_labs.admin as admin

# %% [markdown]
# # Migrate

# %% [markdown]
# ## Migrate all Workspaces from a Capacity <-- Most often used

# %%
source_capacity = '' # Enter the Source capacity name
target_capacity = '' # Enter the Target capacity name (already exists) 

admin.assign_workspaces_to_capacity(
    source_capacity=source_capacity,
    target_capacity=target_capacity,
    workspace=None,
)

# %% [markdown]
# ## Migrate a single Workspace from a Capacity

# %%
source_capacity = '' # Enter the Source capacity name
target_capacity = '' # Enter the Target capacity name (already exists) 

admin.assign_workspaces_to_capacity(
    source_capacity=source_capacity,
    target_capacity=target_capacity,
    workspace='Workspace A name',
)

# %% [markdown]
# ## Migrate a list of Workspaces from a Capacity

# %%
source_capacity = '' # Enter the Source capacity name
target_capacity = '' # Enter the Target capacity name (already exists) 

admin.assign_workspaces_to_capacity(
    source_capacity=source_capacity,
    target_capacity=target_capacity,
    workspace=['Workspace A name','Workspace B name','Workspace C name'],
)
